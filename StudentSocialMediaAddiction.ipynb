# %% [markdown]
# # Students Social Media Addiction
#
# In this Project, we will be using the dataset, [Dataset:Students Social Media Addiction.](https://www.kaggle.com/datasets/adilshamim8/social-media-addiction-vs-relationships?resource=download&SSORegistrationToken=CfDJ8JWxt6IrvD9KktVh6Ttp9j3mk874mXesK--lD37ybnIdMz_eiNAnZ50vSR22mGrKoVb0yHfvAFXvbipO8jlmq3s2wh56-Os-YXG7qJ-1oCt5jSn_gUnfbVAokkRlR1RDqo-cIni8ePLp9m6l_7HYIJjtfacWH_qoRCrdI2jN3upMGwjZxwbaBcsfPFc4P9X4MQzfcCbWPnI9dKXyf685Ci59yHC9QTZ7zSC20iTNDlXqIPnQtGdOzk3VsZo2kmjhpgrOsDBz6vkPL3wVZmsJB9skDzs8bUiVNdrDHvo7qnDBtRhcRrf1zBxLS93HxD3MMDGua8qw4K5tFCkBA0WCSsCYdz8&DisplayName=Ravali%20Suram)
#
#
# Objectives:
#
# - To Identify the correaltion between variables in dataset.
# - To investigate the Ages which has the highest Addiction score.
# - To examine the most used platform according to Age.
# - To find the gender that is more Addicted.

# %% [markdown]
# # Data Prepartion and Cleaning
#
# Data preparation is the process of transforming raw data prior to processing and analysis. Data cleaning is the process of fixing or removing incorrect, corrupted,incorrectly formatted,duplicate,or incomplete data within the dataset.It is an important step prior to processing and often involves reformatting data,making corrections to data and combining datasets to enrich data
#
# Firstly, import the library.We will be using pandas to CSV file

# %%
import pandas as pd

# %% [markdown]
# Read the CSV file. You could see the sample DataFrame

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/ravalisuram/ravalisuram-EDA---Data-Cleaning---Pandas/refs/heads/main/Students%20Social%20Media%20Addiction.csv')

# %%
df
# Out:
#      Student_ID  Age  Gender Academic_Level          Country  \
# 0             1   19  Female  Undergraduate       Bangladesh
# 1             2   22    Male       Graduate            India
# 2             3   20  Female  Undergraduate              USA
# 3             4   18    Male    High School               UK
# 4             5   21    Male       Graduate           Canada
# 5             6   19  Female  Undergraduate        Australia
# 6             7   23    Male       Graduate          Germany
# 7             8   20  Female  Undergraduate           Brazil
# 8             9   18    Male    High School            Japan
# 9            10   21  Female       Graduate      South Korea
# 10           11   19    Male  Undergraduate           France
# 11           12   20  Female  Undergraduate            Spain
# 12           13   22    Male       Graduate            Italy
# 13           14   18  Female    High School           Mexico
# ...

# %% [markdown]
# To Display the max rows we use the below panda function

# %%
pd.set_option('display.max.rows',705)

# %% [markdown]
# By using .drop_duplicates we can check for any duplicte rows

# %%
df = df.drop_duplicates()

df
# Out:
#      Student_ID  Age  Gender Academic_Level          Country  \
# 0             1   19  Female  Undergraduate       Bangladesh
# 1             2   22    Male       Graduate            India
# 2             3   20  Female  Undergraduate              USA
# 3             4   18    Male    High School               UK
# 4             5   21    Male       Graduate           Canada
# 5             6   19  Female  Undergraduate        Australia
# 6             7   23    Male       Graduate          Germany
# 7             8   20  Female  Undergraduate           Brazil
# 8             9   18    Male    High School            Japan
# 9            10   21  Female       Graduate      South Korea
# 10           11   19    Male  Undergraduate           France
# 11           12   20  Female  Undergraduate            Spain
# 12           13   22    Male       Graduate            Italy
# 13           14   18  Female    High School           Mexico
# ...

# %% [markdown]
# By using .columns we can see the column labels of the dataframe

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Academic_Level', 'Country',
#        'Avg_Daily_Usage_Hours', 'Most_Used_Platform',
#        'Affects_Academic_Performance', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score'],
#       dtype='object')

# %% [markdown]
# len function helps in finding the number of rows

# %%
len(df)
# Out:
# 705

# %% [markdown]
# By using .shape attribute we can see the dataframes dimensionality.The result is a tuple containing the number of row and columns

# %%
df.shape
# Out:
# (705, 13)

# %% [markdown]
# In this dataset we have 705 rows and 13 columns

# %% [markdown]
# By using .info attribute, we can see the every column information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
# ...

# %% [markdown]
# Next, we will be identifying whether there is any ocurrence of missing value in the dataset.

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %% [markdown]
# From the above output,we can conclude that there are no missing values in the dataset

# %% [markdown]
# Next, we will drop some unnecessary columns using drop attribute

# %%
df = df.drop(columns = ['Relationship_Status','Affects_Academic_Performance','Student_ID'])

df
# Out:
#      Age  Gender Academic_Level          Country  Avg_Daily_Usage_Hours  \
# 0     19  Female  Undergraduate       Bangladesh                    5.2
# 1     22    Male       Graduate            India                    2.1
# 2     20  Female  Undergraduate              USA                    6.0
# 3     18    Male    High School               UK                    3.0
# 4     21    Male       Graduate           Canada                    4.5
# 5     19  Female  Undergraduate        Australia                    7.2
# 6     23    Male       Graduate          Germany                    1.5
# 7     20  Female  Undergraduate           Brazil                    5.8
# 8     18    Male    High School            Japan                    4.0
# 9     21  Female       Graduate      South Korea                    3.3
# 10    19    Male  Undergraduate           France                    4.8
# 11    20  Female  Undergraduate            Spain                    5.5
# ...

# %% [markdown]
# # Exloratory Analysis and Visualiztion
#
# Exploratory Data Analysis(EDA) is a process of describing the data by means of statistical and visualization techniques in order to bring important aspects of that data into focus for further analysis.This involves inspecting the dataset from many angles, describing & summarizing it without making any assumptions.
#
# Let's begin by importing matplotlib.pyplot and seaborn

# %%
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df.describe()
# Out:
#               Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000             705.000000             705.000000
# mean    20.659574               4.918723               6.868936
# std      1.399217               1.257395               1.126848
# min     18.000000               1.500000               3.800000
# 25%     19.000000               4.100000               6.000000
# 50%     21.000000               4.800000               6.900000
# 75%     22.000000               5.800000               7.700000
# max     24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# std               1.105055                     0.957968        1.587165
# min               4.000000                     0.000000        2.000000
# ...

# %% [markdown]
# ### 1. what is the Relationship between each variable in the dataset?
#
# Let's find the correlation between each column in the dataset and we will round it to 2 decimals

# %%
corr = df.corr(numeric_only = True).round(2)

corr
# Out:
#                               Age  Avg_Daily_Usage_Hours  \
# Age                          1.00                  -0.11
# Avg_Daily_Usage_Hours       -0.11                   1.00
# Sleep_Hours_Per_Night        0.13                  -0.79
# Mental_Health_Score          0.16                  -0.80
# Conflicts_Over_Social_Media -0.18                   0.80
# Addicted_Score              -0.17                   0.83
#
#                              Sleep_Hours_Per_Night  Mental_Health_Score  \
# Age                                           0.13                 0.16
# Avg_Daily_Usage_Hours                        -0.79                -0.80
# Sleep_Hours_Per_Night                         1.00                 0.71
# Mental_Health_Score                           0.71                 1.00
# Conflicts_Over_Social_Media                  -0.68                -0.89
# Addicted_Score                               -0.76                -0.95
#
# ...

# %%
#mask = np.triu(np.ones_like(corr,dtype = bool))

sns.heatmap(corr, annot = True, vmin = -1, vmax = 1, cmap = 'Reds')

plt.show()

# %% [markdown]
# ### 2. what is Age of the studens who has the more Addiction score on average?

# %%
plt.figure(figsize=(15,6))

highest_addiction_age = df.groupby(['Age','Academic_Level'],as_index = False)['Addicted_Score'].mean().round(2)

plt.ylabel('Addicted_Score')
plt.title('Addiction Score by Age')
sns.barplot(x = 'Age', y = 'Addicted_Score', data = highest_addiction_age,hue = 'Academic_Level',palette = 'bright')
# Out:
# <Axes: title={'center': 'Addiction Score by Age'}, xlabel='Age', ylabel='Addicted_Score'>

# %% [markdown]
# ### 3. what is the most used social media platform?

# %%
Most_Used_Platform = df.groupby(['Age','Most_Used_Platform'], as_index = False)['Avg_Daily_Usage_Hours'].mean()

# %%
plt.figure(figsize= (15,8))
sns.lineplot(x = 'Age', y = 'Avg_Daily_Usage_Hours', hue = 'Most_Used_Platform', data = Most_Used_Platform, style = "Most_Used_Platform")
plt.title('Most Used Platform')
# Out:
# Text(0.5, 1.0, 'Most Used Platform')

# %% [markdown]
# ### 4. Which gender has the more Addiction score

# %%
Gender_Addiction = df.groupby('Gender',as_index =  False)['Addicted_Score'].mean(numeric_only = True)

Gender_Addiction
# Out:
#    Gender  Addicted_Score
# 0  Female        6.515581
# 1    Male        6.357955

# %%
sns.barplot(x = 'Gender', y = 'Addicted_Score', data = Gender_Addiction, palette = 'bright', legend = False)
# Out:
# /var/folders/nv/g59prq5x1ps27_5f7f8r3vfr0000gn/T/ipykernel_45074/890885764.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Gender', y = 'Addicted_Score', data = Gender_Addiction, palette = 'bright', legend = False)
# <Axes: xlabel='Gender', ylabel='Addicted_Score'>

# %%
#Top 5 most used social media platforms

top_platforms = df.groupby(['Most_Used_Platform'])['Avg_Daily_Usage_Hours'].mean().sort_values(ascending = False)[:5]

top_platforms
# Out:
# Most_Used_Platform
# WhatsApp     6.475926
# TikTok       5.346104
# Snapchat     5.092308
# WeChat       4.960000
# Instagram    4.872289
# Name: Avg_Daily_Usage_Hours, dtype: float64

# %% [markdown]
# # Inferences and conclusions
#
# From the Analysis of Students Social Media Addiction, a few inferences can be made.
#
# Firstly from, **Question 1** : Based on the Heatmap,We can see that there is negative correlation among Age to Average daily usage hours and to Addiction scores.In **Question 2**: We found that high school academic level students are more addicted to social media according to the mean of Addicted Score by grouping the age and most used platforms.
#
# From **Question 3**: We listed out the top 5 most used platform among them Whatsapp is on the top followed by Tiktok, Snapchat, Wechat and Instagram. Finally from **Question 4** : We can conclude that female students are more addicted to social media compared to male according to mean of Addicted score.
